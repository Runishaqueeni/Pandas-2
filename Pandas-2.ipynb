# %%
import pandas as pd

data=pd.read_csv(r"C:/Users/Rani Motcha FSAG/Documents/Python/brain_tumor_dataset.csv")
data
# Out:
#     Patient_ID   Age  Gender Tumor_Type  Tumor_Size Stage      Symptom_1  \
# 0            1  73.0    Male  Malignant    5.375612   III  Vision Issues
# 1            2  26.0    Male     Benign    4.847098   NaN       Headache
# 2            3   NaN    Male        NaN    5.588391     I            NaN
# 3            4  29.0    Male  Malignant         NaN    IV  Vision Issues
# 4            5  54.0  Female     Benign    2.417506     I       Headache
# ..         ...   ...     ...        ...         ...   ...            ...
# 94          95  75.0    Male  Malignant    9.685120    II         Nausea
# 95          96  57.0    Male        NaN    3.643067    IV            NaN
# 96          97  28.0    Male  Malignant    0.739781    IV       Headache
# 97          98  34.0    Male  Malignant    7.429725   III       Seizures
# 98          99  34.0    Male  Malignant    9.540553   III         Nausea
#
#         Symptom_2      Symptom_3 Radiation_Treatment Surgery_Performed  \
# ...

# %%
data.head(10)
# Out:
#    Patient_ID   Age  Gender Tumor_Type  Tumor_Size Stage      Symptom_1  \
# 0           1  73.0    Male  Malignant    5.375612   III  Vision Issues
# 1           2  26.0    Male     Benign    4.847098   NaN       Headache
# 2           3   NaN    Male        NaN    5.588391     I            NaN
# 3           4  29.0    Male  Malignant         NaN    IV  Vision Issues
# 4           5  54.0  Female     Benign    2.417506     I       Headache
# 5           6  27.0     NaN  Malignant    3.483837     I  Vision Issues
# 6           7  72.0    Male  Malignant         NaN    IV  Vision Issues
# 7           8   NaN    Male     Benign    6.319362   NaN            NaN
# 8           9  50.0    Male     Benign    8.075229    IV  Vision Issues
# 9          10  54.0     NaN     Benign    8.549382     I       Seizures
#
#        Symptom_2      Symptom_3 Radiation_Treatment Surgery_Performed  \
# 0       Seizures       Seizures                  No                No
# ...

# %%
data.tail(10)
# Out:
#     Patient_ID   Age  Gender Tumor_Type  Tumor_Size Stage      Symptom_1  \
# 89          90  65.0  Female        NaN    9.881465    II            NaN
# 90          91  76.0    Male     Benign    7.005252     I       Seizures
# 91          92  27.0  Female  Malignant    7.473097    II  Vision Issues
# 92          93  54.0  Female     Benign         NaN    II  Vision Issues
# 93          94  37.0     NaN     Benign    2.383152     I       Seizures
# 94          95  75.0    Male  Malignant    9.685120    II         Nausea
# 95          96  57.0    Male        NaN    3.643067    IV            NaN
# 96          97  28.0    Male  Malignant    0.739781    IV       Headache
# 97          98  34.0    Male  Malignant    7.429725   III       Seizures
# 98          99  34.0    Male  Malignant    9.540553   III         Nausea
#
#         Symptom_2      Symptom_3 Radiation_Treatment Surgery_Performed  \
# 89       Seizures  Vision Issues                  No               Yes
# ...

# %%
data.describe()
# Out:
#        Patient_ID        Age  Tumor_Size  Survival_Rate  Tumor_Growth_Rate
# count   99.000000  99.000000   99.000000      99.000000          99.000000
# mean    50.000000  49.252525    5.551046      71.874855           1.453776
# std     28.722813  16.814318    2.663866      17.180148           0.920929
# min      1.000000  20.000000    0.739781      40.358423           0.111154
# 25%     25.500000  34.000000    3.355897      57.445583           0.588550
# 50%     50.000000  48.000000    5.797956      72.228719           1.439842
# 75%     74.500000  64.500000    7.702043      86.526084           2.263721
# max     99.000000  79.000000    9.881465      99.986781           2.999594

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Patient_ID           99 non-null     int64
#  1   Age                  90 non-null     float64
#  2   Gender               87 non-null     object
#  3   Tumor_Type           86 non-null     object
#  4   Tumor_Size           86 non-null     float64
#  5   Stage                93 non-null     object
#  6   Symptom_1            86 non-null     object
#  7   Symptom_2            85 non-null     object
#  8   Symptom_3            87 non-null     object
#  9   Radiation_Treatment  88 non-null     object
#  10  Surgery_Performed    90 non-null     object
#  11  Chemotherapy         88 non-null     object
#  12  Survival_Rate        86 non-null     float64
#  13  Tumor_Growth_Rate    87 non-null     float64
#  14  MRI_Result           87 non-null     object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()



data["Survival_Rate"] = label_encoder.fit_transform(data["Survival_Rate"])
print(data)
# Out:
#     Patient_ID   Age  Gender Tumor_Type  Tumor_Size Stage      Symptom_1  \
# 0            1  73.0    Male  Malignant    5.375612   III  Vision Issues
# 1            2  26.0    Male     Benign    4.847098   NaN       Headache
# 2            3   NaN    Male        NaN    5.588391     I            NaN
# 3            4  29.0    Male  Malignant    0.163631    IV  Vision Issues
# 4            5  54.0  Female     Benign    2.417506     I       Headache
# ..         ...   ...     ...        ...         ...   ...            ...
# 94          95  75.0    Male  Malignant    9.685120    II         Nausea
# 95          96  57.0    Male        NaN    3.643067    IV            NaN
# 96          97  28.0    Male  Malignant    0.739781    IV       Headache
# 97          98  34.0    Male  Malignant    7.429725   III       Seizures
# 98          99  34.0    Male  Malignant    9.540553   III         Nausea
#
#         Symptom_2      Symptom_3 Radiation_Treatment Surgery_Performed  \
# ...

# %%
empty_cells = data.isnull()
print(empty_cells)
# Out:
#     Patient_ID    Age  Gender  Tumor_Type  Tumor_Size  Stage  Symptom_1  \
# 0        False  False   False       False       False  False      False
# 1        False  False   False       False       False   True      False
# 2        False   True   False        True       False  False       True
# 3        False  False   False       False        True  False      False
# 4        False  False   False       False       False  False      False
# ..         ...    ...     ...         ...         ...    ...        ...
# 94       False  False   False       False       False  False      False
# 95       False  False   False        True       False  False       True
# 96       False  False   False       False       False  False      False
# 97       False  False   False       False       False  False      False
# 98       False  False   False       False       False  False      False
#
#     Symptom_2  Symptom_3  Radiation_Treatment  Surgery_Performed  \
# ...

# %%
empty_cells = data.isnull().sum()
print(empty_cells)
# Out:
# Patient_ID              0
# Age                     9
# Gender                 12
# Tumor_Type             13
# Tumor_Size             13
# Stage                   6
# Symptom_1              13
# Symptom_2              14
# Symptom_3              12
# Radiation_Treatment    11
# Surgery_Performed       9
# Chemotherapy           11
# Survival_Rate           0
# Tumor_Growth_Rate      12
# MRI_Result             12
# dtype: int64

# %%
x=data["Patient_ID"].mean()
x
# Out:
# 50.0

# %%
x=data["Survival_Rate"].median()
x
# Out:
# 49.0

# %%
x=data["Tumor_Growth_Rate"].mode()
x
# Out:
# 0     0.111154
# 1     0.111876
# 2     0.153079
# 3     0.163631
# 4     0.168874
#         ...
# 82    2.888062
# 83    2.965008
# 84    2.983420
# 85    2.990010
# 86    2.999594
# Name: Tumor_Growth_Rate, Length: 87, dtype: float64

# %%
data["Survival_Rate"]=data["Survival_Rate"].fillna(x)
data["Tumor_Size"]=data["Tumor_Size"].fillna(x)
print(data)
# Out:
#     Patient_ID   Age  Gender Tumor_Type  Tumor_Size Stage      Symptom_1  \
# 0            1  73.0    Male  Malignant    5.375612   III  Vision Issues
# 1            2  26.0    Male     Benign    4.847098   NaN       Headache
# 2            3   NaN    Male        NaN    5.588391     I            NaN
# 3            4  29.0    Male  Malignant    0.163631    IV  Vision Issues
# 4            5  54.0  Female     Benign    2.417506     I       Headache
# ..         ...   ...     ...        ...         ...   ...            ...
# 94          95  75.0    Male  Malignant    9.685120    II         Nausea
# 95          96  57.0    Male        NaN    3.643067    IV            NaN
# 96          97  28.0    Male  Malignant    0.739781    IV       Headache
# 97          98  34.0    Male  Malignant    7.429725   III       Seizures
# 98          99  34.0    Male  Malignant    9.540553   III         Nausea
#
#         Symptom_2      Symptom_3 Radiation_Treatment Surgery_Performed  \
# ...

# %%
data.isnull().sum()
# Out:
# Patient_ID              0
# Age                     9
# Gender                 12
# Tumor_Type             13
# Tumor_Size              1
# Stage                   6
# Symptom_1              13
# Symptom_2              14
# Symptom_3              12
# Radiation_Treatment    11
# Surgery_Performed       9
# Chemotherapy           11
# Survival_Rate           0
# Tumor_Growth_Rate      12
# MRI_Result             12
# dtype: int64

# %%
data.dropna()
# Out:
#     Patient_ID   Age  Gender Tumor_Type  Tumor_Size Stage      Symptom_1  \
# 0            1  73.0    Male  Malignant    5.375612   III  Vision Issues
# 8            9  50.0    Male     Benign    8.075229    IV  Vision Issues
# 15          16  37.0    Male  Malignant    9.583138     I       Headache
# 40          41  48.0    Male  Malignant    1.340483     I         Nausea
# 44          45  78.0    Male     Benign    1.277332    II       Seizures
# 45          46  23.0    Male     Benign    6.133116    II  Vision Issues
# 46          47  31.0    Male  Malignant    3.327370    II       Seizures
# 47          48  27.0    Male     Benign    5.651895   III         Nausea
# 48          49  36.0    Male  Malignant    7.732756    II       Seizures
# 49          50  39.0    Male  Malignant    6.392207     I         Nausea
# 50          51  33.0    Male     Benign    9.333474   III  Vision Issues
# 51          52  46.0  Female     Benign    1.691321     I       Seizures
# ...

# %%
data.dropna(subset=["Tumor_Size"])
# Out:
#     Patient_ID   Age  Gender Tumor_Type  Tumor_Size Stage      Symptom_1  \
# 0            1  73.0    Male  Malignant    5.375612   III  Vision Issues
# 1            2  26.0    Male     Benign    4.847098   NaN       Headache
# 2            3   NaN    Male        NaN    5.588391     I            NaN
# 3            4  29.0    Male  Malignant    0.163631    IV  Vision Issues
# 4            5  54.0  Female     Benign    2.417506     I       Headache
# ..         ...   ...     ...        ...         ...   ...            ...
# 94          95  75.0    Male  Malignant    9.685120    II         Nausea
# 95          96  57.0    Male        NaN    3.643067    IV            NaN
# 96          97  28.0    Male  Malignant    0.739781    IV       Headache
# 97          98  34.0    Male  Malignant    7.429725   III       Seizures
# 98          99  34.0    Male  Malignant    9.540553   III         Nausea
#
#         Symptom_2      Symptom_3 Radiation_Treatment Surgery_Performed  \
# ...

# %%
data.dropna(axis=1)
# Out:
#     Patient_ID  Survival_Rate
# 0            1             11
# 1            2             86
# 2            3              5
# 3            4             12
# 4            5             16
# ..         ...            ...
# 94          95             61
# 95          96             37
# 96          97             86
# 97          98             71
# 98          99             50
#
# [99 rows x 2 columns]
